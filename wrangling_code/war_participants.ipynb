# %% [markdown]
# # Wrangle War Participant Data
#
# ### Input Datasets
#
# - `Inter-StateWarData_v4.0.csv`
# - `INTRA-STATE WARS v5.1 CSV.csv`
# - `Extra-StateWarData_v4.0.csv`
# - `Non-StateWarData_v4.0.csv`
# - `polity.csv`
#
# ### Output Datasets
#
# - `war_participants.csv`

# %%
import pandas as pd
import numpy as np

# %%
raw_data_path = "../data/raw/"
processed_data_path = "../data/processed/"

# %%
dfInterStateWar = pd.read_csv(raw_data_path+"Inter-StateWarData_v4.0.csv", encoding='utf-8', na_values=[-7, -8, -9], dtype={"WarNum": str, "TransFrom": str, "TransTo": str})
dfIntraStateWar = pd.read_csv(raw_data_path+"INTRA-STATE_State_participants v5.1 CSV.csv", encoding='latin-1', na_values=[-7, -8, -9], dtype={"WarNum": str})
dfExtraStateWar = pd.read_csv(raw_data_path+"Extra-StateWarData_v4.0.csv", encoding='latin-1', na_values=[-7, -8, -9], dtype={"WarNum": str, "Interven": bool, "TransFrom": str, "TransTo": str})
dfNonStateWar = pd.read_csv(raw_data_path+"Non-StateWarData_v4.0.csv", encoding='utf-8', na_values=[-7, -8, -9], dtype={"WarNum": str, "TransFrom": str, "TransTo": str})
dfPolities = pd.read_csv(processed_data_path+"polity.csv", encoding='utf-8')

# %% [markdown]
# ## create "war_participants" table
#
# table creation statement
#
# ```
# class War_Participants(Base):
#     __tablename__ = "war_participants"
#
#     war = Column(String(5), primary_key=True)
#     polity = Column(Integer(5), primary_key=True)
#     start_date = Column(Date, primary_key=True)
#     start_date_prec = Column(Text)
#     end_date = Column(Date)
#     end_date_prec = Column(Text)
#     side = Column(String(1))
#     is_initiator = Column(Boolean)
#     outcome = Column(Text)
#     deaths = Column(Integer)
#
#     __table_args__ = (
#         ForeignKeyConstraint(["war"], ["war.id"]),
#         ForeignKeyConstraint(["polity"], ["polity.id"]),
#     )
# ```
#
# #### Notes
#
# Units of observation
#
# - Interstate War: WarNum + ccode + Side
# - Intrastate War: WarNum + CcodeA + CcodeB
# - Extrastate War: WarNum + ccode1 + ccode2
# - Nonstate War: WarNum
#
#
# Outcome Codes
#
# Integrated:
#
# 1 = "won"
# 2 = "lost"
# 3 = "compromise"
# 4 = "transitioned"
# 5 = "war ongoing as of (last updated)"
# 6 = "stalemate"
# 7 = "conflict continues at below war level"
# 8 = "changed sides"
#
# Interstate:
#
# 1 = Winner
# 2 = Loser
# 3 = Compromise/Tied
# 4 = The war was transformed into another type of war
# 5 = The war is ongoing as of 12/31/2007
# 6 = Stalemate
# 7 = Conflict continues at below war level
# 8 = changed sides
#
# Intrastate:
#
# 1 = Side A wins;
# 2 = Side B wins;
# 3 = Compromise;
# 4 = The war was transformed into another type of war;
# 5 = The war is ongoing as of 12/31/2014;
# 6 = Stalemate;
# 7 = Conflict continues at below war level
#
# Nonstate:
#
# 1 - Side A wins
# 2 - Side B wins
# 3 - Compromise
# 4 - The war was transformed into another type of war
# 5 - The war is ongoing as of 12/31/2007
# 6 - Stalemate
# 7 - Conflict continues at below war level
#
# Extrastate:
#
# 1 – Side A wins
# 2 - Side B wins
# 3 - Compromise
# 4 - The war was transformed into another type of war
# 5 - The war is ongoing as of 12/31/2007
# 6 - Stalemate
# 7 - Conflict continues at below war level

# %% [markdown]
# ### common functions

# %%
def process_dates(df, start_year, start_month, start_day, end_year, end_month, end_day):
    """
    For a given dataframe, with the column names provided for the start/end year/month/day,
    create columns for the date precision and the actual date
    """
    df["start_date_prec"] = "day"
    df["start_date_prec"] = df["start_date_prec"]\
        .where(df[start_day].notna(), "month")\
        .where(df[start_month].notna(), "year")

    df["end_date_prec"] = "day"
    df["end_date_prec"] = df["end_date_prec"]\
        .where(df[end_day].notna(), "month")\
        .where(df[end_month].notna(), "year")

    df[start_day] = df[start_day].fillna(1).astype(int)
    df[start_month] = df[start_month].fillna(1).astype(int)
    df[start_year] = df[start_year].fillna(1).astype(int)

    df[end_day] = df[end_day].fillna(1).astype(int)
    df[end_month] = df[end_month].fillna(1).astype(int)
    df[end_year] = df[end_year].fillna(1).astype(int)

    df["start_date"] = pd.to_datetime(df[[start_year, start_month, start_day]].rename(columns={start_year:"year", start_month:"month", start_day:"day"}), errors="coerce")
    df["end_date"] = pd.to_datetime(df[[end_year, end_month, end_day]].rename(columns={end_year:"year", end_month:"month", end_day:"day"}), errors="coerce")
    
    df = df.drop(columns = [start_year, start_month, start_day, end_year, end_month, end_day])
    return df

# %% [markdown]
# ### Interstate War

# %%
dfInterStateWar.head()
# Out:
#   WarNum              WarName  WarType  ccode       StateName  Side  \
# 0      1   Franco-Spanish War        1    230           Spain     2
# 1      1   Franco-Spanish War        1    220          France     1
# 2      4  First Russo-Turkish        1    640  Ottoman Empire     2
# 3      4  First Russo-Turkish        1    365          Russia     1
# 4      7     Mexican-American        1     70          Mexico     2
#
#    StartMonth1  StartDay1  StartYear1  EndMonth1  ...  EndMonth2  EndDay2  \
# 0            4          7        1823         11  ...        NaN      NaN
# 1            4          7        1823         11  ...        NaN      NaN
# 2            4         26        1828          9  ...        NaN      NaN
# 3            4         26        1828          9  ...        NaN      NaN
# 4            4         25        1846          9  ...        NaN      NaN
#
#    EndYear2  TransFrom  WhereFought  Initiator  Outcome  TransTo BatDeath  \
# 0       NaN        503            2          2        2      NaN    600.0
# 1       NaN        503            2          1        1      NaN    400.0
# 2       NaN        506           11          2        2      NaN  80000.0
# 3       NaN        506           11          1        1      NaN  50000.0
# 4       NaN        NaN            1          2        2      NaN   6000.0
#
#    Version
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
#
# [5 rows x 25 columns]

# %%
dfInterStateWar.duplicated(['WarNum','ccode','Side']).sum()
# Out:
# 0

# %%
dfInterStateWar.columns
# Out:
# Index(['WarNum', 'WarName', 'WarType', 'ccode', 'StateName', 'Side',
#        'StartMonth1', 'StartDay1', 'StartYear1', 'EndMonth1', 'EndDay1',
#        'EndYear1', 'StartMonth2', 'StartDay2', 'StartYear2', 'EndMonth2',
#        'EndDay2', 'EndYear2', 'TransFrom', 'WhereFought', 'Initiator',
#        'Outcome', 'TransTo', 'BatDeath', 'Version'],
#       dtype='object')

# %%
dfInterPar_dates1 = dfInterStateWar[['WarNum', 'ccode', 'Side','StartMonth1', 'StartDay1', 'StartYear1', 'EndMonth1', 'EndDay1', 'EndYear1', 'Initiator', 'Outcome', 'BatDeath']]\
.drop_duplicates().dropna(subset=["StartYear1"])
dfInterPar_dates1_proc = process_dates(dfInterPar_dates1, "StartYear1", "StartMonth1", "StartDay1", "EndYear1", "EndMonth1", "EndDay1")

# %%
dfInterPar_dates2 = dfInterStateWar[['WarNum', 'ccode', 'Side', 'StartMonth2', 'StartDay2', 'StartYear2', 'EndMonth2', 'EndDay2', 'EndYear2', 'Initiator', 'Outcome', 'BatDeath']]\
.drop_duplicates().dropna(subset=["StartYear2"])
dfInterPar_dates2_proc = process_dates(dfInterPar_dates2, "StartYear2", "StartMonth2", "StartDay2", "EndYear2", "EndMonth2", "EndDay2")

# %%
dfInterPar = pd.concat([dfInterPar_dates1_proc, dfInterPar_dates2_proc])
dfInterPar
# Out:
#     WarNum  ccode  Side  Initiator  Outcome  BatDeath start_date_prec  \
# 0        1    230     2          2        2     600.0             day
# 1        1    220     1          1        1     400.0             day
# 2        4    640     2          2        2   80000.0             day
# 3        4    365     1          1        1   50000.0             day
# 4        7     70     2          2        2    6000.0             day
# ..     ...    ...   ...        ...      ...       ...             ...
# 200    148    660     2          2        2     500.0             day
# 201    148    663     2          1        2    1000.0             day
# 202    148    645     2          2        2     500.0             day
# 268    184    640     1          1        1    1000.0             day
# 269    184    352     2          2        2     500.0             day
#
#     end_date_prec start_date   end_date
# 0             day 1823-04-07 1823-11-13
# 1             day 1823-04-07 1823-11-13
# 2             day 1828-04-26 1829-09-14
# 3             day 1828-04-26 1829-09-14
# 4             day 1846-04-25 1847-09-14
# ..            ...        ...        ...
# 200           day 1948-10-15 1948-10-31
# 201           day 1948-10-15 1948-10-31
# 202           day 1948-10-15 1948-10-31
# 268           day 1974-08-14 1974-08-16
# 269           day 1974-08-14 1974-08-16
#
# [356 rows x 10 columns]

# %%
dfInterPar = dfInterPar.rename(columns={"WarNum": "war", "ccode": "polity"})

# %%
inter_outcome_map = {1: "won", 
                     2: "lost", 
                     3: "compromised", 
                     4: "war transitioned", 
                     5: "war ongoing as of war_type.last_updated", 
                     6: "stalemate", 
                     7: "conflict continues at below war level", 
                     8: "changed sides",
                    }

# %%
dfInterPar["is_initiator"] = dfInterPar["Initiator"].map({1:True, 2:False})
dfInterPar["side"] = dfInterPar["Side"].map({1:"A", 2:"B"})
dfInterPar["deaths"] = dfInterPar["BatDeath"].astype("Int64")
dfInterPar["outcome"] = dfInterPar["Outcome"].map(inter_outcome_map)
dfInterPar
# Out:
#      war  polity  Side  Initiator  Outcome  BatDeath start_date_prec  \
# 0      1     230     2          2        2     600.0             day
# 1      1     220     1          1        1     400.0             day
# 2      4     640     2          2        2   80000.0             day
# 3      4     365     1          1        1   50000.0             day
# 4      7      70     2          2        2    6000.0             day
# ..   ...     ...   ...        ...      ...       ...             ...
# 200  148     660     2          2        2     500.0             day
# 201  148     663     2          1        2    1000.0             day
# 202  148     645     2          2        2     500.0             day
# 268  184     640     1          1        1    1000.0             day
# 269  184     352     2          2        2     500.0             day
#
#     end_date_prec start_date   end_date  is_initiator side  deaths outcome
# 0             day 1823-04-07 1823-11-13         False    B     600    lost
# 1             day 1823-04-07 1823-11-13          True    A     400     won
# 2             day 1828-04-26 1829-09-14         False    B   80000    lost
# 3             day 1828-04-26 1829-09-14          True    A   50000     won
# 4             day 1846-04-25 1847-09-14         False    B    6000    lost
# ..            ...        ...        ...           ...  ...     ...     ...
# 200           day 1948-10-15 1948-10-31         False    B     500    lost
# 201           day 1948-10-15 1948-10-31          True    B    1000    lost
# 202           day 1948-10-15 1948-10-31         False    B     500    lost
# 268           day 1974-08-14 1974-08-16          True    A    1000     won
# 269           day 1974-08-14 1974-08-16         False    B     500    lost
#
# [356 rows x 14 columns]

# %%
dfInterPar_final = dfInterPar[["war", "polity", "start_date", "start_date_prec", "end_date", "end_date_prec", "side", "is_initiator", "outcome", "deaths"]]
dfInterPar_final
# Out:
#      war  polity start_date start_date_prec   end_date end_date_prec side  \
# 0      1     230 1823-04-07             day 1823-11-13           day    B
# 1      1     220 1823-04-07             day 1823-11-13           day    A
# 2      4     640 1828-04-26             day 1829-09-14           day    B
# 3      4     365 1828-04-26             day 1829-09-14           day    A
# 4      7      70 1846-04-25             day 1847-09-14           day    B
# ..   ...     ...        ...             ...        ...           ...  ...
# 200  148     660 1948-10-15             day 1948-10-31           day    B
# 201  148     663 1948-10-15             day 1948-10-31           day    B
# 202  148     645 1948-10-15             day 1948-10-31           day    B
# 268  184     640 1974-08-14             day 1974-08-16           day    A
# 269  184     352 1974-08-14             day 1974-08-16           day    B
#
#      is_initiator outcome  deaths
# 0           False    lost     600
# 1            True     won     400
# 2           False    lost   80000
# 3            True     won   50000
# 4           False    lost    6000
# ..            ...     ...     ...
# 200         False    lost     500
# 201          True    lost    1000
# 202         False    lost     500
# 268          True     won    1000
# 269         False    lost     500
#
# [356 rows x 10 columns]

# %%
dfInterPar_final.duplicated(subset=["war", "polity", "start_date"]).sum()
# Out:
# 0

# %% [markdown]
# ## Intrastate War

# %%
dfIntraStateWar
# Out:
#     WarNum                                  WarName  V5Region  WarType  \
# 0      500          First Caucasus War of 1818-1822         3      5.0
# 1      502      First Two Sicilies War of 1820-1821         3      4.0
# 2      502      First Two Sicilies War of 1820-1821         3      4.0
# 3    502.1         Ali Pasha Rebellion of 1820-1822         3      5.0
# 4      503                 Sardinian Revolt of 1821         3      4.0
# ..     ...                                      ...       ...      ...
# 588  992.5    Somali-Al-Shabaab war of 2014-present         4      4.0
# 589    993               Donbas War of 2014-present         3      5.0
# 590    993               Donbas War of 2014-present         3      5.0
# 591    994  Second Libyan Civil War of 2014-present         5      4.0
# 592    997               Rada'a War of 2014-present         5      7.0
#
#      CcodeA           SideA  CcodeB                SideB  Intnl  StartMo1  \
# 0     365.0          Russia     NaN      Caucasus Rebels      0       6.0
# 1     300.0         Austria     NaN                  NaN      1       3.0
# 2     329.0    Two Sicilies     NaN             Liberals      1       7.0
# 3     640.0  Ottoman Empire     NaN  Ali Pasha Loyalists      0       7.0
# 4     300.0         Austria     NaN                  NaN      1       4.0
# ..      ...             ...     ...                  ...    ...       ...
# 588   530.0        Ethiopia     NaN                  NaN      1       3.0
# 589     NaN             NaN   365.0               Russia      1       8.0
# 590   369.0         Ukraine     NaN          Separatists      1       4.0
# 591   620.0           Libya     NaN          Libyan Dawn      0       5.0
# 592     NaN   Houthi Rebels     NaN                 AQAP      0       9.0
#
#      ...  Outcome  TransTo  Deaths A  Deaths B  TotalBDeaths  \
# 0    ...      1.0      NaN    5000.0    6000.0       11000.0
# 1    ...      1.0      NaN       NaN       NaN           NaN
# 2    ...      1.0      NaN       NaN       NaN        2000.0
# 3    ...      1.0      NaN       NaN       NaN        2000.0
# 4    ...      1.0      NaN       NaN       NaN           NaN
# ..   ...      ...      ...       ...       ...           ...
# 588  ...      5.0      NaN       NaN       NaN           NaN
# 589  ...      5.0      NaN       NaN     220.0           NaN
# 590  ...      5.0      NaN    4000.0    2500.0        6700.0
# 591  ...      3.0      NaN       NaN       NaN        2000.0
# 592  ...      4.0    233.0    1000.0     350.0        1350.0
#
#      SideAPeakTotForces  SideAPeak TheatForces  SideBPeakTotForces  \
# 0             1001000.0                70300.0                 NaN
# 1              273000.0                60000.0                 NaN
# 2               49000.0                10000.0                 NaN
# 3              200000.0                20000.0                 NaN
# 4              273000.0                 2000.0                 NaN
# ..                  ...                    ...                 ...
# 588            138000.0                 4395.0                 NaN
# 589                 NaN                    NaN            798000.0
# 590            204000.0               250000.0                 NaN
# 591              7000.0                30000.0                 NaN
# 592                 NaN               200000.0                 NaN
#
#      SideBPeakTheatForces  Version
# 0                 46000.0      5.1
# 1                     NaN      5.1
# 2                 50000.0      5.1
# 3                 13500.0      5.1
# 4                     NaN      5.1
# ..                    ...      ...
# 588                   NaN      5.1
# 589               12000.0      5.1
# 590               25000.0      5.1
# 591               50000.0      5.1
# 592                3000.0      5.1
#
# [593 rows x 47 columns]

# %%
dfIntraStateWar.columns
# Out:
# Index(['WarNum', 'WarName', 'V5Region', 'WarType', 'CcodeA', 'SideA', 'CcodeB',
#        'SideB', 'Intnl', 'StartMo1', 'StartDy1', 'StartYr1', 'EndMo1',
#        'EndDy1', 'EndYr1', 'StartMo2', 'StartDy2', 'StartYr2', 'EndMo2',
#        'EndDy2', 'EndYr2', 'StartMo3', 'StartDy3', 'StartYr3', 'EndMo3',
#        'EndDy3', 'EndYr3', 'StartMo4', 'StartDy4', 'StartYr4', 'EndMo4',
#        'EndDy4', 'EndYr4', 'WDuratDays', 'WDuratMo', 'TransFrom', 'Initiator',
#        'Outcome', 'TransTo', 'Deaths A', 'Deaths B', 'TotalBDeaths',
#        'SideAPeakTotForces', 'SideAPeak TheatForces', 'SideBPeakTotForces',
#        'SideBPeakTheatForces', 'Version'],
#       dtype='object')

# %%
dfIntraStateWar_dates1 = dfIntraStateWar[['WarNum', 'CcodeA', 'SideA', 'CcodeB', 'SideB', 'StartMo1', 'StartDy1', 'StartYr1', 'EndMo1', 'EndDy1', 'EndYr1', 'WDuratDays', 'WDuratMo', 'Initiator', 'Outcome', 'Deaths A', 'Deaths B', 'TotalBDeaths', 'SideAPeakTotForces', 'SideAPeak TheatForces', 'SideBPeakTotForces', 'SideBPeakTheatForces']]\
.drop_duplicates().dropna(subset=["StartYr1"])
dfIntraStateWar_dates1_proc = process_dates(dfIntraStateWar_dates1, "StartYr1", "StartMo1", "StartDy1", "EndYr1", "EndMo1", "EndDy1")

# %%
dfIntraStateWar_dates1_proc
# Out:
#     WarNum  CcodeA           SideA  CcodeB                SideB  WDuratDays  \
# 0      500   365.0          Russia     NaN      Caucasus Rebels        1596
# 1      502   300.0         Austria     NaN                  NaN           9
# 2      502   329.0    Two Sicilies     NaN             Liberals         262
# 3    502.1   640.0  Ottoman Empire     NaN  Ali Pasha Loyalists         550
# 4      503   300.0         Austria     NaN                  NaN          32
# ..     ...     ...             ...     ...                  ...         ...
# 588  992.5   530.0        Ethiopia     NaN                  NaN         659
# 589    993     NaN             NaN   365.0               Russia         370
# 590    993   369.0         Ukraine     NaN          Separatists         493
# 591    994   620.0           Libya     NaN          Libyan Dawn         572
# 592    997     NaN   Houthi Rebels     NaN                 AQAP         189
#
#      WDuratMo       Initiator  Outcome  Deaths A  Deaths B  TotalBDeaths  \
# 0       53.20        Chechnya      1.0    5000.0    6000.0       11000.0
# 1        0.30             NaN      1.0       NaN       NaN           NaN
# 2        8.73        Liberals      1.0       NaN       NaN        2000.0
# 3       18.33  Ottoman Empire      1.0       NaN       NaN        2000.0
# 4        1.07             NaN      1.0       NaN       NaN           NaN
# ..        ...             ...      ...       ...       ...           ...
# 588     21.97             NaN      5.0       NaN       NaN           NaN
# 589     12.33             NaN      5.0       NaN     220.0           NaN
# 590     16.43     Separatists      5.0    4000.0    2500.0        6700.0
# 591     19.07           Libya      3.0       NaN       NaN        2000.0
# 592      6.30   Houthi Rebels      4.0    1000.0     350.0        1350.0
#
#      SideAPeakTotForces  SideAPeak TheatForces  SideBPeakTotForces  \
# 0             1001000.0                70300.0                 NaN
# 1              273000.0                60000.0                 NaN
# 2               49000.0                10000.0                 NaN
# 3              200000.0                20000.0                 NaN
# 4              273000.0                 2000.0                 NaN
# ..                  ...                    ...                 ...
# 588            138000.0                 4395.0                 NaN
# 589                 NaN                    NaN            798000.0
# 590            204000.0               250000.0                 NaN
# 591              7000.0                30000.0                 NaN
# 592                 NaN               200000.0                 NaN
#
#      SideBPeakTheatForces start_date_prec end_date_prec start_date   end_date
# 0                 46000.0             day         month 1818-06-10 1822-11-01
# 1                     NaN           month           day 1821-03-01 1821-03-23
# 2                 50000.0             day           day 1820-07-02 1821-03-23
# 3                 13500.0           month           day 1820-07-01 1822-01-24
# 4                     NaN             day           day 1821-04-07 1821-05-08
# ..                    ...             ...           ...        ...        ...
# 588                   NaN             day          year 2014-03-03        NaT
# 589               12000.0             day          year 2014-08-15        NaT
# 590               25000.0             day          year 2014-04-15        NaT
# 591               50000.0             day          year 2014-05-16        NaT
# 592                3000.0             day          year 2014-09-16        NaT
#
# [593 rows x 20 columns]

# %% [markdown]
# ## Extrastate War

# %%
dfExtraStateWar
# Out:
#     WarNum                        WarName  WarType  ccode1              SideA  \
# 0      300  Allied Bombardment of Algiers        3   210.0        Netherlands
# 1      300  Allied Bombardment of Algiers        3   200.0     United Kingdom
# 2      301                Ottoman-Wahhabi        3   640.0     Ottoman Empire
# 3      302            Liberation of Chile        2   230.0              Spain
# 4      303       First Bolivar Expedition        2   230.0              Spain
# ..     ...                            ...      ...     ...                ...
# 193    482               Iraqi Resistance        3   290.0             Poland
# 194    482               Iraqi Resistance        3   325.0              Italy
# 195    482               Iraqi Resistance        3   369.0            Ukraine
# 196    482               Iraqi Resistance        3   645.0               Iraq
# 197    482               Iraqi Resistance        3   732.0  Republic of Korea
#
#      ccode2                       SideB  StartMonth1  StartDay1  StartYear1  \
# 0       NaN                         NaN          8.0       26.0        1816
# 1       NaN                     Algeria          8.0       26.0        1816
# 2       NaN              Saudi Wahhabis          9.0        NaN        1816
# 3       NaN  San Martin revolutionaries          1.0        9.0        1817
# 4       NaN                 New Granada          4.0       11.0        1817
# ..      ...                         ...          ...        ...         ...
# 193     NaN                         NaN          3.0        NaN        2004
# 194     NaN                         NaN          3.0        NaN        2004
# 195     NaN                         NaN          3.0        NaN        2004
# 196     NaN                         NaN          6.0       28.0        2004
# 197     NaN                         NaN          9.0       25.0        2004
#
#      ...  EndYear2  Initiator  Interven  TransFrom  Outcome  TransTo  \
# 0    ...       NaN          1      True        NaN        1      NaN
# 1    ...       NaN          1      True        NaN        1      NaN
# 2    ...       NaN          1     False        NaN        1      NaN
# 3    ...       NaN          0     False        NaN        2      NaN
# 4    ...       NaN          1     False        NaN        2      NaN
# ..   ...       ...        ...       ...        ...      ...      ...
# 193  ...       NaN          0      True        227        5      NaN
# 194  ...       NaN          0      True        227        5      NaN
# 195  ...       NaN          0      True        227        5      NaN
# 196  ...       NaN          0      True        227        5      NaN
# 197  ...       NaN          0      True        227        5      NaN
#
#      WhereFought  BatDeath  NonStateDeaths  Version
# 0              6      13.0             NaN        4
# 1              6     129.0          6000.0        4
# 2              6   13500.0         14000.0        4
# 3              1    1700.0          1140.0        4
# 4              1    3000.0          2000.0        4
# ..           ...       ...             ...      ...
# 193            6      23.0             NaN        4
# 194            6      33.0             NaN        4
# 195            6      18.0             NaN        4
# 196            6   10800.0             NaN        4
# 197            6       1.0             NaN        4
#
# [198 rows x 28 columns]

# %%
dfExtraStateWar.columns
# Out:
# Index(['WarNum', 'WarName', 'WarType', 'ccode1', 'SideA', 'ccode2', 'SideB',
#        'StartMonth1', 'StartDay1', 'StartYear1', 'EndMonth1', 'EndDay1',
#        'EndYear1', 'StartMonth2', 'StartDay2', 'StartYear2', 'EndMonth2',
#        'EndDay2 ', 'EndYear2', 'Initiator', 'Interven', 'TransFrom', 'Outcome',
#        'TransTo', 'WhereFought', 'BatDeath', 'NonStateDeaths', 'Version'],
#       dtype='object')

# %%
dfExtraStateWar_dates1 = dfExtraStateWar[['WarNum', 'ccode1', 'SideA', 'ccode2', 'SideB', 'StartMonth1', 'StartDay1', 'StartYear1', 'EndMonth1', 'EndDay1','EndYear1', 'Initiator', 'Outcome', 'BatDeath', 'NonStateDeaths']]\
.drop_duplicates().dropna(subset=["StartYear1"])
dfExtraStateWar_dates1_proc = process_dates(dfExtraStateWar_dates1, "StartYear1", "StartMonth1", "StartDay1", "EndYear1", "EndMonth1", "EndDay1")

# %%
dfExtraStateWar_dates1_proc
# Out:
#     WarNum  ccode1              SideA  ccode2                       SideB  \
# 0      300   210.0        Netherlands     NaN                         NaN
# 1      300   200.0     United Kingdom     NaN                     Algeria
# 2      301   640.0     Ottoman Empire     NaN              Saudi Wahhabis
# 3      302   230.0              Spain     NaN  San Martin revolutionaries
# 4      303   230.0              Spain     NaN                 New Granada
# ..     ...     ...                ...     ...                         ...
# 193    482   290.0             Poland     NaN                         NaN
# 194    482   325.0              Italy     NaN                         NaN
# 195    482   369.0            Ukraine     NaN                         NaN
# 196    482   645.0               Iraq     NaN                         NaN
# 197    482   732.0  Republic of Korea     NaN                         NaN
#
#      Initiator  Outcome  BatDeath  NonStateDeaths start_date_prec  \
# 0            1        1      13.0             NaN             day
# 1            1        1     129.0          6000.0             day
# 2            1        1   13500.0         14000.0           month
# 3            0        2    1700.0          1140.0             day
# 4            1        2    3000.0          2000.0             day
# ..         ...      ...       ...             ...             ...
# 193          0        5      23.0             NaN           month
# 194          0        5      33.0             NaN           month
# 195          0        5      18.0             NaN           month
# 196          0        5   10800.0             NaN             day
# 197          0        5       1.0             NaN             day
#
#     end_date_prec start_date   end_date
# 0             day 1816-08-26 1816-08-30
# 1             day 1816-08-26 1816-08-30
# 2             day 1816-09-01 1818-09-11
# 3             day 1817-01-09 1818-04-05
# 4             day 1817-04-11 1819-08-10
# ..            ...        ...        ...
# 193           day 2004-03-01 2006-03-31
# 194          year 2004-03-01        NaT
# 195         month 2004-03-01 2005-10-01
# 196          year 2004-06-28        NaT
# 197          year 2004-09-25        NaT
#
# [198 rows x 13 columns]

# %%
dfExtraStateWar_dates2 = dfExtraStateWar[['WarNum', 'ccode1', 'SideA', 'ccode2', 'SideB', 'StartMonth2', 'StartDay2', 'StartYear2', 'EndMonth2', 'EndDay2 ','EndYear2', 'Initiator', 'Outcome', 'BatDeath', 'NonStateDeaths']]\
.drop_duplicates().dropna(subset=["StartYear2"])
dfExtraStateWar_dates2_proc = process_dates(dfExtraStateWar_dates2, "StartYear2", "StartMonth2", "StartDay2", "EndYear2", "EndMonth2", "EndDay2 ")

# %%
dfExtraStateWar_dates2_proc
# Out:
#     WarNum  ccode1           SideA  ccode2         SideB  Initiator  Outcome  \
# 37     334   210.0     Netherlands     NaN          Bali          1        6
# 79     379   200.0  United Kingdom     NaN   Afghanistan          1        1
# 153    454   200.0  United Kingdom     NaN  Palestinians          0        1
#
#      BatDeath  NonStateDeaths start_date_prec end_date_prec start_date  \
# 37      300.0          2000.0             day           day 1849-04-02
# 79    10000.0         11000.0             day           day 1879-09-03
# 153     126.0          2450.0           month         month 1937-08-01
#
#       end_date
# 37  1849-06-14
# 79  1880-09-02
# 153 1939-01-01

# %%
dfExtraPar = pd.concat([dfExtraStateWar_dates1_proc, dfExtraStateWar_dates2_proc])

# %%
dfExtraPar
# Out:
#     WarNum  ccode1              SideA  ccode2                       SideB  \
# 0      300   210.0        Netherlands     NaN                         NaN
# 1      300   200.0     United Kingdom     NaN                     Algeria
# 2      301   640.0     Ottoman Empire     NaN              Saudi Wahhabis
# 3      302   230.0              Spain     NaN  San Martin revolutionaries
# 4      303   230.0              Spain     NaN                 New Granada
# ..     ...     ...                ...     ...                         ...
# 196    482   645.0               Iraq     NaN                         NaN
# 197    482   732.0  Republic of Korea     NaN                         NaN
# 37     334   210.0        Netherlands     NaN                        Bali
# 79     379   200.0     United Kingdom     NaN                 Afghanistan
# 153    454   200.0     United Kingdom     NaN                Palestinians
#
#      Initiator  Outcome  BatDeath  NonStateDeaths start_date_prec  \
# 0            1        1      13.0             NaN             day
# 1            1        1     129.0          6000.0             day
# 2            1        1   13500.0         14000.0           month
# 3            0        2    1700.0          1140.0             day
# 4            1        2    3000.0          2000.0             day
# ..         ...      ...       ...             ...             ...
# 196          0        5   10800.0             NaN             day
# 197          0        5       1.0             NaN             day
# 37           1        6     300.0          2000.0             day
# 79           1        1   10000.0         11000.0             day
# 153          0        1     126.0          2450.0           month
#
#     end_date_prec start_date   end_date
# 0             day 1816-08-26 1816-08-30
# 1             day 1816-08-26 1816-08-30
# 2             day 1816-09-01 1818-09-11
# 3             day 1817-01-09 1818-04-05
# 4             day 1817-04-11 1819-08-10
# ..            ...        ...        ...
# 196          year 2004-06-28        NaT
# 197          year 2004-09-25        NaT
# 37            day 1849-04-02 1849-06-14
# 79            day 1879-09-03 1880-09-02
# 153         month 1937-08-01 1939-01-01
#
# [201 rows x 13 columns]

# %% [markdown]
# ## Nonstate War

# %%
dfNonStateWar
# Out:
#    WarNum                    WarName  WarType  WhereFought  \
# 0    1500     First Maori Tribal War        8            9
# 1    1501       Shaka Zulu-Bantu War        8            4
# 2    1502            Burma-Assam War        8            7
# 3    1503           Buenos Aires War        8            1
# 4    1505    Second Maori Tribal War        8            9
# ..    ...                        ...      ...          ...
# 57   1574  Rwandan Social Revolution        8            4
# 58   1577   Dhofar Rebellion Phase 1        8            6
# 59   1581        Angola Guerilla War        8            4
# 60   1582  East Timorese War Phase 1        8            7
# 61   1594            Hemda-Lendu War        9            4
#
#                       SideA1    SideA2      SideB1       SideB2  \
# 0   Te Rauparaha's Ngati Toa       NaN    Taranaki    Ngai Tahu
# 1                 Shaka Zulu       NaN       Bantu          NaN
# 2                      Burma       NaN       Assam          NaN
# 3               Buenos Aires       NaN   Provinces          NaN
# 4     Hongi Hika's Nga Phuhi       NaN  Ngati Paoa   Ngati Maru
# ..                       ...       ...         ...          ...
# 57                      Hutu       NaN       Tutsi          NaN
# 58                    Dhofar       NaN        Oman          NaN
# 59                      MPLA       NaN        FLNA        UNITA
# 60                  Fretilin   Apodeti         UDT          NaN
# 61                     Hemda       NaN       Lendu          NaN
#
#                   SideB3      SideB4  ... EndMonth  EndDay  Initiator  \
# 0                Waikato   Ngati Ira  ...      NaN     NaN          A
# 1                    NaN         NaN  ...      9.0    24.0          A
# 2                    NaN         NaN  ...      NaN     NaN          A
# 3                    NaN         NaN  ...      2.0    23.0          B
# 4    Waikato River Maori    Te Arawa  ...      NaN     NaN          A
# ..                   ...         ...  ...      ...     ...        ...
# 57                   NaN         NaN  ...      7.0     1.0          A
# 58                   NaN         NaN  ...     10.0     6.0          A
# 59                   NaN         NaN  ...     10.0    22.0          A
# 60                   NaN         NaN  ...     10.0    15.0          B
# 61                   NaN         NaN  ...      3.0     NaN          B
#
#     TransFrom  TransTo  Outcome  SideADeaths SideBDeaths TotalCombatDeaths  \
# 0         NaN      NaN        1       1500.0      6000.0              7500
# 1         NaN      NaN        1      20000.0     40000.0             60000
# 2         NaN      NaN        1          NaN         NaN               NaN
# 3         NaN      NaN        2          NaN         NaN               NaN
# 4         NaN      NaN        1        500.0      2000.0              2500
# ..        ...      ...      ...          ...         ...               ...
# 57        NaN      NaN        1          NaN         NaN               NaN
# 58        NaN      NaN        6          NaN         NaN              5000
# 59        NaN      186        4          NaN         NaN               NaN
# 60        NaN      472        4          NaN         NaN              3000
# 61        NaN      NaN        6          NaN         NaN               NaN
#
#    Version
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
# ..     ...
# 57       4
# 58       4
# 59       4
# 60       4
# 61       4
#
# [62 rows x 25 columns]

# %%
dfNonStateWar.columns
# Out:
# Index(['WarNum', 'WarName', 'WarType', 'WhereFought', 'SideA1', 'SideA2',
#        'SideB1', 'SideB2', 'SideB3', 'SideB4', 'SideB5', 'StartYear',
#        'StartMonth', 'StartDay', 'EndYear', 'EndMonth', 'EndDay', 'Initiator',
#        'TransFrom', 'TransTo', 'Outcome', 'SideADeaths', 'SideBDeaths',
#        'TotalCombatDeaths', 'Version'],
#       dtype='object')

# %%
dfNonStateWar_dates = dfNonStateWar[['WarNum', 'SideA1', 'SideA2', 'SideB1', 'SideB2', 'SideB3', 'SideB4', 'SideB5', 'StartYear', 'StartMonth', 'StartDay', 'EndYear', 'EndMonth', 'EndDay', 'Initiator', 'Outcome', 'SideADeaths', 'SideBDeaths', 'TotalCombatDeaths',]]\
.drop_duplicates()
dfNonStateWar_dates_proc = process_dates(dfNonStateWar_dates, "StartYear", "StartMonth", "StartDay", "EndYear", "EndMonth", "EndDay")

# %%
dfNonStateWar_dates_proc
# Out:
#    WarNum                    SideA1    SideA2      SideB1       SideB2  \
# 0    1500  Te Rauparaha's Ngati Toa       NaN    Taranaki    Ngai Tahu
# 1    1501                Shaka Zulu       NaN       Bantu          NaN
# 2    1502                     Burma       NaN       Assam          NaN
# 3    1503              Buenos Aires       NaN   Provinces          NaN
# 4    1505    Hongi Hika's Nga Phuhi       NaN  Ngati Paoa   Ngati Maru
# ..    ...                       ...       ...         ...          ...
# 57   1574                      Hutu       NaN       Tutsi          NaN
# 58   1577                    Dhofar       NaN        Oman          NaN
# 59   1581                      MPLA       NaN        FLNA        UNITA
# 60   1582                  Fretilin   Apodeti         UDT          NaN
# 61   1594                     Hemda       NaN       Lendu          NaN
#
#                   SideB3      SideB4      SideB5 Initiator  Outcome  \
# 0                Waikato   Ngati Ira  Rangitikei         A        1
# 1                    NaN         NaN         NaN         A        1
# 2                    NaN         NaN         NaN         A        1
# 3                    NaN         NaN         NaN         B        2
# 4    Waikato River Maori    Te Arawa         NaN         A        1
# ..                   ...         ...         ...       ...      ...
# 57                   NaN         NaN         NaN         A        1
# 58                   NaN         NaN         NaN         A        6
# 59                   NaN         NaN         NaN         A        4
# 60                   NaN         NaN         NaN         B        4
# 61                   NaN         NaN         NaN         B        6
#
#     SideADeaths  SideBDeaths TotalCombatDeaths start_date_prec end_date_prec  \
# 0        1500.0       6000.0              7500            year          year
# 1       20000.0      40000.0             60000            year           day
# 2           NaN          NaN               NaN            year          year
# 3           NaN          NaN               NaN             day           day
# 4         500.0       2000.0              2500           month          year
# ..          ...          ...               ...             ...           ...
# 57          NaN          NaN               NaN             day           day
# 58          NaN          NaN              5000           month           day
# 59          NaN          NaN               NaN             day           day
# 60          NaN          NaN              3000             day           day
# 61          NaN          NaN               NaN           month         month
#
#    start_date   end_date
# 0  1818-01-01 1824-01-01
# 1  1819-01-01 1828-09-24
# 2  1819-01-01 1822-01-01
# 3  1820-01-08 1820-02-23
# 4  1821-09-01 1823-01-01
# ..        ...        ...
# 57 1959-10-19 1962-07-01
# 58 1968-09-01 1971-10-06
# 59 1974-10-15 1975-10-22
# 60 1975-08-11 1975-10-15
# 61 1999-06-01 2005-03-01
#
# [62 rows x 17 columns]
